# %%
    from poser import *

# %%
    o = __name__ == '__main__'
    the.requests_cache.install_cache('ten')()
    site = "http://conda-forge.org/"
    platform = 'linux'
    __file__ = globals().get('__file__', 'forge.ipynb')
    anaconda = """https://conda.anaconda.org/conda-forge/{platform}-64/repodata.json"""

# %%
    data = a[anaconda.format].requests.get().methodcaller('json')[
        a.get('packages').pandas.DataFrame().pandas.DataFrame.transpose()
    ]

# %%
    o and f"""{len(data(platform='linux').name.drop_duplicates())} conda-forge {platform} packages"""
# Out:
# '3977 conda-forge linux packages'

# %%
    df = a.pandas.concat()((
            data(platform=platform) for platform in ['linux', 'win', 'osx']))
    packages = df.groupby(('name', 'platform')).agg({'name': 'count'})[['name']].unstack('platform').fillna(0).gt(0)['name'].reset_index()

# %%
    packages
# Out:
# platform           name  linux   osx    win
# 0               ad3-cpp   True  True   True
# 1              adaptive   True  True   True
# 2                addict   True  True   True
# 3                 adept   True  True  False
# 4                   ads   True  True   True
# 5                 aenum   True  True   True
# 6                affine   True  True   True
# 7                 agate   True  True   True
# 8             agate-dbf   True  True   True
# 9           agate-excel   True  True   True
# 10         agate-lookup   True  True   True
# 11         agate-remote   True  True   True
# 12            agate-sql   True  True   True
# 13          agate-stats   True  True   True
# 14           agg-regrid   True  True   True
# 15          aiobotocore   True  True   True
# 16        aioeasywebdav   True  True   True
# 17             aiofiles   True  True   True
# 18              aiohttp   True  True   True
# 19             aiomysql   True  True   True
# ...

# %%
    platforms = packages.set_index('name').sum().to_frame('packages').T

# %%
    platforms
# Out:
# platform  linux   osx   win
# packages   3977  3939  3369
