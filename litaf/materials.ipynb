# %% [markdown]
# ## Notebooks are a Hypothesis

# %%
    if __name__ == '__main__':
        # %reload_ext pidgin
        # %pidgin @../macros
    from poser import *
    __file__ = globals().get('__file__', 'materials.ipynb')
# Out:
# <sweet.test.Result run=18 errors=0 failures=0>

# %%
{% for _ in range(4) %}# [Perez](http://github.com/fperez) for Pre{{['cedent', 'sident'][_==2]}}
{% endfor %}

    graph {rankdir="LR"; data--science--computing--data}

[![Data Driven Journalism](https://camo.githubusercontent.com/a8d4be63da2f73339f35839d4c006f080b13104a/68747470733a2f2f75706c6f61642e77696b696d656469612e6f72672f77696b6970656469612f636f6d6d6f6e732f342f34382f446174615f64726976656e5f6a6f75726e616c69736d5f70726f636573732e6a7067)]()

#### ["Literate computing" and computational reproducibility: IPython in the age of data-driven journalism]()
> Our job with Jupyter~~IPython~~ is to think deeply about questions regarding the intersection of _**computing, data and science**_, but it's clear to me at this point that we can contribute in contexts beyond pure scientific research. I hope we'll be able to provide folks who have a _**direct intersection with the public**_, such as journalists, with tools that help a more informed and productive debate.
# Out:
# # [Perez](http://github.com/fperez) for Precedent
# # [Perez](http://github.com/fperez) for Precedent
# # [Perez](http://github.com/fperez) for President
# # [Perez](http://github.com/fperez) for Precedent
#
#
#     graph {rankdir="LR"; data--science--computing--data}
#
# [![Data Driven Journalism](https://camo.githubusercontent.com/a8d4be63da2f73339f35839d4c006f080b13104a/68747470733a2f2f75706c6f61642e77696b696d656469612e6f72672f77696b6970656469612f636f6d6d6f6e732f342f34382f446174615f64726976656e5f6a6f75726e616c69736d5f70726f636573732e6a7067)]()
#
# #### ["Literate computing" and computational reproducibility: IPython in the age of data-driven journalism]()
# ...

# %%
    graph {rankdir="LR" compound=true
           subgraph cluster_literacy {label="Pillars of Literacy" Material -- Cognitive -- Social -- Material}
           Social -- {Textual Computational}[ltail=cluster_literacy]
          }
> ... “literacy” as a human facility with a **symbolic** and **infrastructural technology**—such as a textual writing system—that can be used for **creative, communicative and rhetorical** purposes. Literacy enables people to represent their ideas in texts that can travel away from immediate, interpersonal contexts (**to write**) and also to interpret texts produced by others (**to read**).
>> [Annette Vee - Understanding Computer programming as a Literacy](http://licsjournal.org/OJS/index.php/LiCS/article/view/24/26)
# Out:
#     graph {rankdir="LR" compound=true
#            subgraph cluster_literacy {label="Pillars of Literacy" Material -- Cognitive -- Social -- Material}
#            Social -- {Textual Computational}[ltail=cluster_literacy]
#           }
# > ... “literacy” as a human facility with a **symbolic** and **infrastructural technology**—such as a textual writing system—that can be used for **creative, communicative and rhetorical** purposes. Literacy enables people to represent their ideas in texts that can travel away from immediate, interpersonal contexts (**to write**) and also to interpret texts produced by others (**to read**).
# >> [Annette Vee - Understanding Computer programming as a Literacy](http://licsjournal.org/OJS/index.php/LiCS/article/view/24/26)

# %%
    http://www.cs.yale.edu/homes/perlis-alan/quotes.html
# Out:
#     http://www.cs.yale.edu/homes/perlis-alan/quotes.html
#         <iframe
#             width="800"
#             height="600"
#             src="http://www.cs.yale.edu/homes/perlis-alan/quotes.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
![](http://nbviewer.jupyter.org/github/jupyterday-atlanta-2016/oriole_jupyterday_atl/blob/master/don_knuth.jpg)


* [$\TeX$](https://en.wikipedia.org/wiki/TeX)
* [The Art of Computer Programming](https://en.wikipedia.org/wiki/The_Art_of_Computer_Programming)
* [40 years of tests!](http://yakshav.es/the-patron-saint-of-yakshaves/)
* [Book of the Century](https://web.archive.org/web/20080820030403/http://www.americanscientist.org/bookshelf/pub/100-or-so-books-that-shaped-a-century-of-science)
# Out:
# ![](http://nbviewer.jupyter.org/github/jupyterday-atlanta-2016/oriole_jupyterday_atl/blob/master/don_knuth.jpg)
#
#
# * [$\TeX$](https://en.wikipedia.org/wiki/TeX)
# * [The Art of Computer Programming](https://en.wikipedia.org/wiki/The_Art_of_Computer_Programming)
# * [40 years of tests!](http://yakshav.es/the-patron-saint-of-yakshaves/)
# * [Book of the Century](https://web.archive.org/web/20080820030403/http://www.americanscientist.org/bookshelf/pub/100-or-so-books-that-shaped-a-century-of-science)

# %%
>> - [Donald Knuth](https://en.wikipedia.org/wiki/Donald_Knuth) - [Literate Programming](http://roxygen.org/knuth-literate-programming.pdf)

> # By coining the phrase “literate programming,” I am imposing a moral commitment on everyone who hears the term; surely nobody wants to admit writing an illiterate program.
# Out:
# >> - [Donald Knuth](https://en.wikipedia.org/wiki/Donald_Knuth) - [Literate Programming](http://roxygen.org/knuth-literate-programming.pdf)
#
# > # By coining the phrase “literate programming,” I am imposing a moral commitment on everyone who hears the term; surely nobody wants to admit writing an illiterate program.

# %%
    digraph {rankdir="LR"; subgraph clusterc{ label="literate computing"; data->"interactive computing" ->data -> "literate programming" ->data} {"interactive computing" "literate programming"} -> machines "literate programming" -> people {machines people} -> 🙉🙈🙊}
# Out:
#     digraph {rankdir="LR"; subgraph clusterc{ label="literate computing"; data->"interactive computing" ->data -> "literate programming" ->data} {"interactive computing" "literate programming"} -> machines "literate programming" -> people {machines people} -> 🙉🙈🙊}

# %%
# Computing is a Diverse Action

<img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Programming_paradigms.svg/1379px-Programming_paradigms.svg.png" width="800"/>
# Out:
# # Computing is a Diverse Action
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Programming_paradigms.svg/1379px-Programming_paradigms.svg.png" width="800"/>

# %%
## [Python is a glue language](https://docs.scipy.org/doc/numpy/user/c-info.python-as-glue.html)

#### Visualization and Exploration
    
    import pandas, altair, bokeh, seaborn,  matplotlib, holoviews
    
#### Machine Learning

    import sklearn, tpot
    
#### Functional Programming

    import toolz, poser

#### Async programming

    import dask, tornado
    
#### C

    import cython, ctypes

#### Fortran
    
    from numpy import f2py
    
#### Java
    
    import pyspark

#### Other Shit

    from numba import jit
# Out:
# ## [Python is a glue language](https://docs.scipy.org/doc/numpy/user/c-info.python-as-glue.html)
#
# #### Visualization and Exploration
#
#     import pandas, altair, bokeh, seaborn,  matplotlib, holoviews
#
# #### Machine Learning
#
#     import sklearn, tpot
#
# #### Functional Programming
#
#     import toolz, poser
#
# #### Async programming
#
#     import dask, tornado
#
# #### C
#
#     import cython, ctypes
#
# #### Fortran
#
#     from numpy import f2py
#
# #### Java
#
#     import pyspark
#
# #### Other Shit
#
#     from numba import jit

# %%
    
    def testImports():
        """Test if all of the Python Glue examples imported"""
        assert all((
            pandas, altair, bokeh, seaborn, matplotlib, holoviews, sklearn, tpot, toolz, poser, dask, tornado, cython, ctypes, f2py, pyspark
        )), """Some modules were not loaded."""
# Out:
# <sweet.test.Result run=2 errors=0 failures=0>

# %%
    pandas.read_html("https://github.com/jupyter/jupyter/wiki/Jupyter-kernels")[0]
# Out:
#     pandas.read_html("https://github.com/jupyter/jupyter/wiki/Jupyter-kernels")[0]
#                         Name         Jupyter/IPython Version  \
# 0            Coarray-Fortran                     Jupyter 4.0
# 1                 sparkmagic                   Jupyter >=4.0
# 2                 sas_kernel                     Jupyter 4.0
# 3                  IPyKernel                     Jupyter 4.0
# 4                     IJulia                             NaN
# 5                   IHaskell                             NaN
# 6                      IRuby                             NaN
# 7                IJavascript                             NaN
# 8             jpCoffeescript                             NaN
# 9                    ICSharp                     Jupyter 4.0
# 10                  IRKernel                     IPython 3.0
# 11                  SageMath                       Jupyter 4
# 12              pari_jupyter                       Jupyter 4
# ...

# %%
    a.IPython.display.YouTubeVideo('ZwNCUetnccw')(width=800)

> The ethical, social, epistemological and technical reasons for the origin of [@ProjectJupyter](https://twitter.com/ProjectJupyter) mirror the reasons for the origin of [@ThePSF](https://twitter.com/ThePSF)
>> [mdpacer](https://twitter.com/mdpacer/status/986385176098828290)
# Out:
#     a.IPython.display.YouTubeVideo('ZwNCUetnccw')(width=800)
#
# > The ethical, social, epistemological and technical reasons for the origin of [@ProjectJupyter](https://twitter.com/ProjectJupyter) mirror the reasons for the origin of [@ThePSF](https://twitter.com/ThePSF)
# >> [mdpacer](https://twitter.com/mdpacer/status/986385176098828290)

# %%
---

> We compare mass ability to read and write so ware with mass literacy, and predict equally pervasive changes to society. Hardware is now sufficiently fast and cheap to make mass computer education possible: the next big change will happen when most computer users have the knowledge and power to create and modify software.
> > Guido van Rossum, from a 1999 DARPA grant application to support the teaching of computer programming.
# Out:
# ---
#
# > We compare mass ability to read and write so ware with mass literacy, and predict equally pervasive changes to society. Hardware is now sufficiently fast and cheap to make mass computer education possible: the next big change will happen when most computer users have the knowledge and power to create and modify software.
# > > Guido van Rossum, from a 1999 DARPA grant application to support the teaching of computer programming.

# %%
    https://www.nature.com/news/1-500-scientists-lift-the-lid-on-reproducibility-1.19970
# Out:
#     https://www.nature.com/news/1-500-scientists-lift-the-lid-on-reproducibility-1.19970
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.nature.com/news/1-500-scientists-lift-the-lid-on-reproducibility-1.19970"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
    https://www.theatlantic.com/science/archive/2018/04/the-scientific-paper-is-obsolete/556676/
# Out:
#     https://www.theatlantic.com/science/archive/2018/04/the-scientific-paper-is-obsolete/556676/
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.theatlantic.com/science/archive/2018/04/the-scientific-paper-is-obsolete/556676/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
    https://leanpub.com/modernscientist
# Out:
#     https://leanpub.com/modernscientist
#         <iframe
#             width="800"
#             height="600"
#             src="https://leanpub.com/modernscientist"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
    http://gael-varoquaux.info/programming/of-software-and-science-reproducible-science-what-why-and-how.html

* __Replicability (Readability)__: being able to redo an experiment from scratch.
* __Reproducibility__: being able to rerun an experiment as it was run, for instance by reanalysing data.
* __Reusability__: applying the process to a new yet similar question.
    
---
# Out:
#     http://gael-varoquaux.info/programming/of-software-and-science-reproducible-science-what-why-and-how.html
#
# * __Replicability (Readability)__: being able to redo an experiment from scratch.
# * __Reproducibility__: being able to rerun an experiment as it was run, for instance by reanalysing data.
# * __Reusability__: applying the process to a new yet similar question.
#
# ---
#         <iframe
#             width="800"
#             height="600"
#             src="http://gael-varoquaux.info/programming/of-software-and-science-reproducible-science-what-why-and-how.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Reusability is Procedural Literacy

> ... procedural literacy entails the ability to reconfigure basic concepts and rules to understand and solve problems, not just on the computer, but in general.
>> [Ian Bogost - Procedural Literacy: Problem Solving with Programming, Systems, & Play](http://bogost.com/downloads/I.%20Bogost%20Procedural%20Literacy.pdf)
# Out:
# # Reusability is Procedural Literacy
#
# > ... procedural literacy entails the ability to reconfigure basic concepts and rules to understand and solve problems, not just on the computer, but in general.
# >> [Ian Bogost - Procedural Literacy: Problem Solving with Programming, Systems, & Play](http://bogost.com/downloads/I.%20Bogost%20Procedural%20Literacy.pdf)
